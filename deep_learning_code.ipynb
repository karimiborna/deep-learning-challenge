# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
application_df = application_df.drop(columns=['EIN','NAME'])
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
#  YOUR CODE GOES HERE
application_types = application_df['APPLICATION_TYPE'].value_counts()
application_types
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
application_types_to_replace = application_types.loc[lambda x: x < 500].index

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
#  YOUR CODE GOES HERE
classification_types = application_df['CLASSIFICATION'].value_counts()
classification_types
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE
class_over_1 = classification_types.loc[lambda x: x>1]
class_over_1
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
classifications_to_replace = application_df['CLASSIFICATION'].value_counts().loc[lambda x: x < 1000].index
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
dummies = pd.get_dummies(application_df)
dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34299 entries, 0 to 34298
# Data columns (total 44 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   STATUS                        34299 non-null  int64
#  1   ASK_AMT                       34299 non-null  int64
#  2   IS_SUCCESSFUL                 34299 non-null  int64
#  3   APPLICATION_TYPE_Other        34299 non-null  uint8
#  4   APPLICATION_TYPE_T10          34299 non-null  uint8
#  5   APPLICATION_TYPE_T19          34299 non-null  uint8
#  6   APPLICATION_TYPE_T3           34299 non-null  uint8
#  7   APPLICATION_TYPE_T4           34299 non-null  uint8
#  8   APPLICATION_TYPE_T5           34299 non-null  uint8
#  9   APPLICATION_TYPE_T6           34299 non-null  uint8
#  10  APPLICATION_TYPE_T7           34299 non-null  uint8
#  11  APPLICATION_TYPE_T8           34299 non-null  uint8
#  12  AFFILIATION_CompanySponsored  34299 non-null  uint8
# ...

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE
X = dummies.drop(columns=['IS_SUCCESSFUL'])
y = dummies['IS_SUCCESSFUL']
# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=15)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn_model1 = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn_model1.add(tf.keras.layers.Dense(units=100, activation="relu", input_dim=43))
# Second hidden layer
#  YOUR CODE GOES HERE
nn_model1.add(tf.keras.layers.Dense(units=30, activation="relu"))
# Output layer
#  YOUR CODE GOES HERE
nn_model1.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the model
nn_model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 100)               4400
#
#  dense_1 (Dense)             (None, 30)                3030
#
#  dense_2 (Dense)             (None, 1)                 31
#
# ...
# Total params: 7,461
# Trainable params: 7,461
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn_model1.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
#  YOUR CODE GOES HERE
fit_model = nn_model1.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5704 - accuracy: 0.7212
# Epoch 2/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5546 - accuracy: 0.7305
# Epoch 3/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5524 - accuracy: 0.7296
# Epoch 4/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5499 - accuracy: 0.7313
# Epoch 5/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5489 - accuracy: 0.7337
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5477 - accuracy: 0.7326
# Epoch 7/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5472 - accuracy: 0.7321
# Epoch 8/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5465 - accuracy: 0.7345
# Epoch 9/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5463 - accuracy: 0.7328
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model1.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5650 - accuracy: 0.7277 - 469ms/epoch - 2ms/step
# Loss: 0.5650065541267395, Accuracy: 0.7276967763900757

# %%
#Try 2:
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE
nn_model2 = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn_model2.add(tf.keras.layers.Dense(units=80, activation="tanh", input_dim=43))
# Second hidden layer
#  YOUR CODE GOES HERE
nn_model2.add(tf.keras.layers.Dense(units=40, activation="tanh"))
# Third hidden layer
#  YOUR CODE GOES HERE
nn_model2.add(tf.keras.layers.Dense(units=20, activation="relu"))
# Fourth hidden layer
#  YOUR CODE GOES HERE
nn_model2.add(tf.keras.layers.Dense(units=5, activation="relu"))
# Output layer
#  YOUR CODE GOES HERE
nn_model2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the model
print(nn_model2.summary())
nn_model2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_18 (Dense)            (None, 80)                3520
#
#  dense_19 (Dense)            (None, 40)                3240
#
#  dense_20 (Dense)            (None, 20)                820
#
#  dense_21 (Dense)            (None, 5)                 105
#
#  dense_22 (Dense)            (None, 1)                 6
#
# ...
# Total params: 7,691
# Trainable params: 7,691
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
fit_model = nn_model2.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5726 - accuracy: 0.7233
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5551 - accuracy: 0.7310
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5522 - accuracy: 0.7308
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5505 - accuracy: 0.7317
# Epoch 5/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5491 - accuracy: 0.7329
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5481 - accuracy: 0.7333
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5472 - accuracy: 0.7345
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5467 - accuracy: 0.7339
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5456 - accuracy: 0.7349
# Epoch 10/100
# ...

# %%
model_loss2, model_accuracy2 = nn_model2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss2}, Accuracy: {model_accuracy2}")
# Out:
# 268/268 - 0s - loss: 0.5677 - accuracy: 0.7283 - 451ms/epoch - 2ms/step
# Loss: 0.5676628947257996, Accuracy: 0.7282798886299133

# %%
#Try 3:
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE
nn_model3 = tf.keras.models.Sequential()
# First hidden layer
#  YOUR CODE GOES HERE
nn_model3.add(tf.keras.layers.Dense(units=100, activation="relu", input_dim=43))
# Second hidden layer
#  YOUR CODE GOES HERE
nn_model3.add(tf.keras.layers.Dense(units=75, activation="relu"))
# Third hidden layer
#  YOUR CODE GOES HERE
nn_model3.add(tf.keras.layers.Dense(units=40, activation="tanh"))
# Fourth hidden layer
#  YOUR CODE GOES HERE
nn_model3.add(tf.keras.layers.Dense(units=27, activation="tanh"))
# Fifth hidden layer
#  YOUR CODE GOES HERE
nn_model3.add(tf.keras.layers.Dense(units=14, activation="sigmoid"))
# Sixth hidden layer
#  YOUR CODE GOES HERE
nn_model3.add(tf.keras.layers.Dense(units=2, activation="sigmoid"))
# Output layer
#  YOUR CODE GOES HERE
nn_model3.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the model
print(nn_model3.summary())
nn_model3.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_42 (Dense)            (None, 100)               4400
#
#  dense_43 (Dense)            (None, 75)                7575
#
#  dense_44 (Dense)            (None, 40)                3040
#
#  dense_45 (Dense)            (None, 27)                1107
#
#  dense_46 (Dense)            (None, 14)                392
#
#  dense_47 (Dense)            (None, 2)                 30
#
#  dense_48 (Dense)            (None, 1)                 3
#
# ...
# Total params: 16,547
# Trainable params: 16,547
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
fit_model = nn_model3.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.6088 - accuracy: 0.6969
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5773 - accuracy: 0.7287
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5668 - accuracy: 0.7315
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5608 - accuracy: 0.7321
# Epoch 5/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5579 - accuracy: 0.7313
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5564 - accuracy: 0.7328
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5557 - accuracy: 0.7325
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5530 - accuracy: 0.7338
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5515 - accuracy: 0.7344
# Epoch 10/100
# ...

# %%
model_loss3, model_accuracy3 = nn_model3.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss3}, Accuracy: {model_accuracy3}")
# Out:
# 268/268 - 1s - loss: 0.5584 - accuracy: 0.7286 - 519ms/epoch - 2ms/step
# Loss: 0.5583807826042175, Accuracy: 0.7286297082901001

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn_model3.save("my_model.h5")
